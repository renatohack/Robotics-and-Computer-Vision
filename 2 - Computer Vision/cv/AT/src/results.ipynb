# %%
import tensorflow as tf
import numpy
import matplotlib.pyplot as plt
import pickle
import os
from tensorflow import keras
import pandas
from seaborn import boxplot
from sklearn.metrics import accuracy_score, ConfusionMatrixDisplay, confusion_matrix, RocCurveDisplay

# %%
# IMPORT IMAGES
dir_images_train = "C:\\zImagens\\train"
image_size = (128,128)
batch_size = 32

# TRAINING
the_seed = 32
input_shape = image_size + (1,)
convnn_activation = 'relu'
fully_connected_activation = 'tanh'
hyperparameter_max = 10
learning_rate = 0.001
patience = 25
max_epochs = patience * 40
score_metric = 'accuracy'
verbose = 0
phi = 359
n_folds = 5

# %%
model_dir = "C:\\zImagens"

list_dir = os.listdir(model_dir)
list_dir = [x for x in list_dir if "RPS_H" in x]

# %%
result_list = []

for dir in list_dir:
    net_name = dir
    hyperparameter = int(dir.split("_")[1].replace("H", ""))
    fold = int(dir.split("_")[2].replace("F", ""))
    
    rps_net = keras.models.load_model(f"C:\\zImagens\\{dir}")
    
    with open(f"C:\\zImagens\\{dir}\\{dir}", "rb") as file_pi:
        history = pickle.load(file_pi)
    
    training_score = history[score_metric][-1]
    validation_score = history[f'val_{score_metric}'][-1]
    
    
    
    result_list.append((net_name, hyperparameter, fold, training_score, validation_score, rps_net, history))
    
results = pandas.DataFrame.from_records(result_list)
results.columns = ["net_name", 'hyperparameter', "kfold", 'accuracy', 'val_accuracy', "rps", "history"]
results.sort_values("val_accuracy", ascending = False)
# Out:
#       net_name  hyperparameter  kfold  accuracy  val_accuracy
# 11   RPS_H2_F1               2      1  0.994727      0.992616  \
# 38   RPS_H7_F3               7      3  0.994991      0.992616
# 24   RPS_H4_F4               4      4  0.994727      0.991561
# 14   RPS_H2_F4               2      4  0.993936      0.991561
# 22   RPS_H4_F2               4      2  0.993145      0.991561
# 45   RPS_H9_F0               9      0  0.988924      0.990516
# 18   RPS_H3_F3               3      3  0.995782      0.990506
# 27   RPS_H5_F2               5      2  0.988927      0.990506
# 35   RPS_H7_F0               7      0  0.988924      0.989463
# 21   RPS_H4_F1               4      1  0.988663      0.989451
# 23   RPS_H4_F3               4      3  0.983654      0.989451
# 15   RPS_H3_F0               3      0  0.993407      0.988409
# 37   RPS_H7_F2               7      2  0.986291      0.988397
# 19   RPS_H3_F4               3      4  0.995518      0.988397
# 33   RPS_H6_F3               6      3  0.988927      0.988397
# 40   RPS_H8_F0               8      0  0.987606      0.987355
# 8    RPS_H1_F3               1      3  0.989191      0.987342
# 16   RPS_H3_F1               3      1  0.980754      0.987342
# 5    RPS_H1_F0               1      0  0.990770      0.986301
# 10   RPS_H2_F0               2      0  0.996308      0.986301
# 0   RPS_H10_F0              10      0  0.986023      0.986301
# 12   RPS_H2_F2               2      2  0.993936      0.986287
# 48   RPS_H9_F3               9      3  0.994200      0.986287
# 25   RPS_H5_F0               5      0  0.986023      0.985248
# 20   RPS_H4_F0               4      0  0.992352      0.985248
# 41   RPS_H8_F1               8      1  0.990245      0.985232
# 2   RPS_H10_F2              10      2  0.976272      0.985232
# 49   RPS_H9_F4               9      4  0.978645      0.985232
# 26   RPS_H5_F1               5      1  0.993673      0.984177
# 46   RPS_H9_F1               9      1  0.982072      0.983122
# 30   RPS_H6_F0               6      0  0.988924      0.982086
# 17   RPS_H3_F2               3      2  0.992091      0.982068
# 28   RPS_H5_F3               5      3  0.988400      0.981013
# 9    RPS_H1_F4               1      4  0.991036      0.981013
# 6    RPS_H1_F1               1      1  0.990245      0.981013
# 4   RPS_H10_F4              10      4  0.969154      0.978903
# 36   RPS_H7_F1               7      1  0.985763      0.978903
# 31   RPS_H6_F1               6      1  0.994200      0.977848
# 13   RPS_H2_F3               2      3  0.986818      0.976793
# 7    RPS_H1_F2               1      2  0.987345      0.973629
# 1   RPS_H10_F1              10      1  0.979963      0.973629
# 44   RPS_H8_F4               8      4  0.989454      0.972574
# 29   RPS_H5_F4               5      4  0.989982      0.898734
# 34   RPS_H6_F4               6      4  0.991827      0.879747
# 39   RPS_H7_F4               7      4  0.982863      0.867089
# 43   RPS_H8_F3               8      3  0.329554      0.330169
# 3   RPS_H10_F3              10      3  0.329554      0.330169
# 42   RPS_H8_F2               8      2  0.329818      0.329114
# 47   RPS_H9_F2               9      2  0.329818      0.329114
# 32   RPS_H6_F2               6      2  0.329818      0.329114
#
#                                                   rps
# 11  <keras.engine.functional.Functional object at ...  \
# 38  <keras.engine.functional.Functional object at ...
# 24  <keras.engine.functional.Functional object at ...
# 14  <keras.engine.functional.Functional object at ...
# 22  <keras.engine.functional.Functional object at ...
# 45  <keras.engine.functional.Functional object at ...
# 18  <keras.engine.functional.Functional object at ...
# 27  <keras.engine.functional.Functional object at ...
# 35  <keras.engine.functional.Functional object at ...
# 21  <keras.engine.functional.Functional object at ...
# 23  <keras.engine.functional.Functional object at ...
# 15  <keras.engine.functional.Functional object at ...
# 37  <keras.engine.functional.Functional object at ...
# 19  <keras.engine.functional.Functional object at ...
# 33  <keras.engine.functional.Functional object at ...
# 40  <keras.engine.functional.Functional object at ...
# 8   <keras.engine.functional.Functional object at ...
# 16  <keras.engine.functional.Functional object at ...
# 5   <keras.engine.functional.Functional object at ...
# 10  <keras.engine.functional.Functional object at ...
# 0   <keras.engine.functional.Functional object at ...
# 12  <keras.engine.functional.Functional object at ...
# 48  <keras.engine.functional.Functional object at ...
# 25  <keras.engine.functional.Functional object at ...
# 20  <keras.engine.functional.Functional object at ...
# 41  <keras.engine.functional.Functional object at ...
# 2   <keras.engine.functional.Functional object at ...
# 49  <keras.engine.functional.Functional object at ...
# 26  <keras.engine.functional.Functional object at ...
# 46  <keras.engine.functional.Functional object at ...
# 30  <keras.engine.functional.Functional object at ...
# 17  <keras.engine.functional.Functional object at ...
# 28  <keras.engine.functional.Functional object at ...
# 9   <keras.engine.functional.Functional object at ...
# 6   <keras.engine.functional.Functional object at ...
# 4   <keras.engine.functional.Functional object at ...
# 36  <keras.engine.functional.Functional object at ...
# 31  <keras.engine.functional.Functional object at ...
# 13  <keras.engine.functional.Functional object at ...
# 7   <keras.engine.functional.Functional object at ...
# 1   <keras.engine.functional.Functional object at ...
# 44  <keras.engine.functional.Functional object at ...
# 29  <keras.engine.functional.Functional object at ...
# 34  <keras.engine.functional.Functional object at ...
# 39  <keras.engine.functional.Functional object at ...
# 43  <keras.engine.functional.Functional object at ...
# 3   <keras.engine.functional.Functional object at ...
# 42  <keras.engine.functional.Functional object at ...
# 47  <keras.engine.functional.Functional object at ...
# 32  <keras.engine.functional.Functional object at ...
#
#                                               history
# 11  {'loss': [0.9595548510551453, 0.60682553052902...
# 38  {'loss': [1.0546486377716064, 0.66730672121047...
# 24  {'loss': [0.9792642593383789, 0.61009401082992...
# 14  {'loss': [0.9190273284912109, 0.62619864940643...
# 22  {'loss': [0.8770908713340759, 0.55221045017242...
# 45  {'loss': [0.845235288143158, 0.528613507747650...
# 18  {'loss': [0.9210649728775024, 0.63345021009445...
# 27  {'loss': [0.8972600102424622, 0.56442737579345...
# 35  {'loss': [0.8051021099090576, 0.50871562957763...
# 21  {'loss': [0.9690499305725098, 0.63508051633834...
# 23  {'loss': [0.9792658090591431, 0.60432511568069...
# 15  {'loss': [0.8859198689460754, 0.54746985435485...
# 37  {'loss': [0.9059338569641113, 0.52264320850372...
# 19  {'loss': [0.9237508177757263, 0.56994360685348...
# 33  {'loss': [0.94679194688797, 0.5955548882484436...
# 40  {'loss': [0.8426120281219482, 0.51013851165771...
# 8   {'loss': [0.9598828554153442, 0.71695804595947...
# 16  {'loss': [0.9612353444099426, 0.63634377717971...
# 5   {'loss': [0.9727367758750916, 0.77965295314788...
# 10  {'loss': [0.9182491898536682, 0.65516686439514...
# 0   {'loss': [0.8231118321418762, 0.52176976203918...
# 12  {'loss': [0.8831539154052734, 0.58603310585021...
# 48  {'loss': [1.1011182069778442, 1.09861159324646...
# 25  {'loss': [0.862392008304596, 0.587702989578247...
# 20  {'loss': [0.8304557800292969, 0.57099974155426...
# 41  {'loss': [1.059177041053772, 0.905332088470459...
# 2   {'loss': [0.809769332408905, 0.457385003566741...
# 49  {'loss': [1.0305588245391846, 0.61241769790649...
# 26  {'loss': [0.892076849937439, 0.555751681327819...
# 46  {'loss': [0.968201756477356, 0.505389094352722...
# 30  {'loss': [0.8610005378723145, 0.54837149381637...
# 17  {'loss': [0.9376661777496338, 0.63674944639205...
# 28  {'loss': [0.9836180806159973, 0.65319192409515...
# 9   {'loss': [0.9758719205856323, 0.75802791118621...
# 6   {'loss': [0.9500084519386292, 0.70851558446884...
# 4   {'loss': [1.0163244009017944, 0.60142821073532...
# 36  {'loss': [1.0140297412872314, 0.70287036895751...
# 31  {'loss': [0.9072756171226501, 0.53347206115722...
# 13  {'loss': [0.9123960137367249, 0.61820650100708...
# 7   {'loss': [0.9407234787940979, 0.68391638994216...
# 1   {'loss': [0.799956202507019, 0.480268567800521...
# 44  {'loss': [1.0714367628097534, 0.95405000448226...
# 29  {'loss': [0.9082952737808228, 0.50114077329635...
# 34  {'loss': [0.873116135597229, 0.513445198535919...
# 39  {'loss': [1.0949405431747437, 0.77190643548965...
# 43  {'loss': [1.1062802076339722, 1.09861159324646...
# 3   {'loss': [1.107995867729187, 1.098611474037170...
# 42  {'loss': [1.1058794260025024, 1.09861004352569...
# 47  {'loss': [1.1021809577941895, 1.08090531826019...
# 32  {'loss': [1.111404538154602, 1.098608374595642...

# %%
fig = plt.figure(figsize = (12, 7))
ax = fig.add_subplot(111)
boxplot(results, x = 'hyperparameter', y = 'accuracy', ax = ax)
ax.grid()

# %%
dir_images_test = "C:\\zImagens\\imagensreais_control"

test_ds = tf.keras.utils.image_dataset_from_directory(
    directory=dir_images_test,
    labels='inferred',
    label_mode='int',
    class_names=None,
    color_mode='grayscale',
    batch_size=1,
    image_size=image_size,
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False
)

test_images = []
test_labels = []

for image, label in test_ds:
    test_images.append(image.numpy())
    test_labels.append(label.numpy())

test_images = numpy.concatenate(test_images, axis = 0)
test_labels = numpy.concatenate(test_labels, axis = 0)
# Out:
# Found 9 files belonging to 3 classes.

# %%
best_model = results.sort_values(f'val_{score_metric}', ascending = False).head(1)['rps'].values[0]
best_model_predict = best_model.predict(test_images)
best_model_predict = numpy.argmax(best_model_predict, axis = 1)
best_model_history = results.sort_values(f'val_{score_metric}', ascending = False).head(1)['history'].values[0]
print(accuracy_score(test_labels, best_model_predict))

class_names = test_ds.class_names
# Out:
# 1/1 [==============================] - 0s 23ms/step
# 1.0

# %%
best_epoch = len(best_model_history['loss'][:-patience - 1])
best_val_loss = best_model_history['val_loss'][-patience - 1]
best_val_metric = best_model_history[f'val_{score_metric}'][-patience - 1]

fig = plt.figure(figsize=(12, 6))
ax = fig.add_subplot(111)
_ = ax.plot(best_model_history['loss'], label='loss', linewidth=3)
_ = ax.plot(best_model_history['val_loss'], label = 'val_loss', linewidth=3)
_ = ax.scatter(x=[best_epoch], y=[best_val_loss], marker='*', s=1000, color='green')
_ = ax.grid(which='both')
_ = ax.set_xlim([0, len(best_model_history['loss'])])
_ = plt.xlabel('Epoch')
_ = plt.ylabel('loss')
_ = ax.legend(loc='upper right')
_ = ax.annotate(f'Melhor Rede: {100.0*best_val_metric:.0f}% {score_metric.lower()} {best_epoch} epoch',
                (best_epoch, best_val_loss),
                (1.025*best_epoch, 1.33*best_val_loss))

# %%
# plt.figure(figsize=(10, 10))
# for images, labels in test_ds.take(1):
#   for i in range(9):
#     ax = plt.subplot(3, 3, i + 1)
#     plt.imshow(images[i].numpy().astype("uint8"), cmap="gray")
#     plt.title(class_names[int(labels[i])])
#     plt.axis("off")
    
class_names = ['paper', 'rock', 'scissors']

plt.figure(figsize=(6,6))
for i in range(9):
    plt.subplot(3,3,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(test_images[i], cmap="gray")
    plt.xlabel(class_names[test_labels[i]])
plt.show()

# %%
# for image_id in range(0, len(best_model_predict) - 1):
#     print(f"TRUE CLASS: {class_names[test_labels[image_id]]} >> PREDICTED CLASS: {class_names[best_model_predict[image_id]]}")
#     # Y_test[image_id, :]
#     pyplot.imshow(test_images[image_id], cmap='gray')
#     accuracy_score(test_labels, best_model_predict)

image_id = 5
print(f"TRUE CLASS: {class_names[test_labels[image_id]]} >> PREDICTED CLASS: {class_names[best_model_predict[image_id]]}")
# Y_test[image_id, :]
plt.imshow(test_images[image_id], cmap='gray')
accuracy_score(test_labels, best_model_predict)
# Out:
# TRUE CLASS: rock >> PREDICTED CLASS: rock
# 1.0

# %%
ConfusionMatrixDisplay.from_predictions(test_labels, best_model_predict)
print(class_names)
# Out:
# ['paper', 'rock', 'scissors']
